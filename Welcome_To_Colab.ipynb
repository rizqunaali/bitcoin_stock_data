# %% [markdown]
# <a href="https://colab.research.google.com/github/rizqunaali/bitcoin_stock_data/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # BIGDATA Kumpulan Data Harga Bitcoin
# # Nama : muhammad rizquna ali akbar, Nim : 24.11.6095
# # Nama : Bryan Anarki, Nim : 24.11.6080

# %%
# Import library
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # cara 1 : Upload Dataset dari lokal computer

# %%
# Cara 1: Upload Dataset dari lokal komputer
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-38f4b917-72d2-43d7-bd61-406ace1e53f9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-38f4b917-72d2-43d7-bd61-406ace1e53f9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Membaca dataset yang diunggah dari lokal
df_lokal = pd.read_csv("bitcoin_stock_data.csv") # Sesuaikan nama file jika berbeda
df_lokal.head(10)
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2014-09-17  465.864014  468.174011  452.421997  457.334015  457.334015
# 1  2014-09-18  456.859985  456.859985  413.104004  424.440002  424.440002
# 2  2014-09-19  424.102997  427.834991  384.532013  394.795990  394.795990
# 3  2014-09-20  394.673004  423.295990  389.882996  408.903992  408.903992
# 4  2014-09-21  408.084991  412.425995  393.181000  398.821014  398.821014
# 5  2014-09-22  399.100006  406.915985  397.130005  402.152008  402.152008
# 6  2014-09-23  402.091003  441.557007  396.196014  435.790985  435.790985
# 7  2014-09-24  435.897003  436.174011  419.204010  424.393005  424.393005
# 8  2014-09-25  424.017014  425.001007  400.802002  404.424988  404.424988
# 9  2014-09-26  403.946014  408.324005  395.546997  399.518005  399.518005
#
#      Volume
# 0  21056800
# 1  34483200
# 2  37919700
# 3  36863600
# 4  26580100
# 5  24127600
# 6  40739600
# 7  26268600
# 8  27491400
# 9  22882400

# %% [markdown]
# #2.uploade dataset dari google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Ganti 'dataset' dengan nama folder asli yang Anda buat di Google Drive
path_drive = "/content/drive/MyDrive/fg/bitcoin_stock_data.csv"

df_drive = pd.read_csv(path_drive)
df_drive.head(10)
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2014-09-17  465.864014  468.174011  452.421997  457.334015  457.334015
# 1  2014-09-18  456.859985  456.859985  413.104004  424.440002  424.440002
# 2  2014-09-19  424.102997  427.834991  384.532013  394.795990  394.795990
# 3  2014-09-20  394.673004  423.295990  389.882996  408.903992  408.903992
# 4  2014-09-21  408.084991  412.425995  393.181000  398.821014  398.821014
# 5  2014-09-22  399.100006  406.915985  397.130005  402.152008  402.152008
# 6  2014-09-23  402.091003  441.557007  396.196014  435.790985  435.790985
# 7  2014-09-24  435.897003  436.174011  419.204010  424.393005  424.393005
# 8  2014-09-25  424.017014  425.001007  400.802002  404.424988  404.424988
# 9  2014-09-26  403.946014  408.324005  395.546997  399.518005  399.518005
#
#      Volume
# 0  21056800
# 1  34483200
# 2  37919700
# 3  36863600
# 4  26580100
# 5  24127600
# 6  40739600
# 7  26268600
# 8  27491400
# 9  22882400

# %%
# To find the correct path, you can list the contents of your Google Drive.
# For example, to list the contents of your 'MyDrive' folder:
# !ls /content/drive/MyDrive

# If your file is in a subfolder like 'dataset', you can list its contents:
# !ls /content/drive/MyDrive/dataset

# Once you find the correct path and file name, update the 'path_drive' variable below.
# Out:
#  17015652021486224185890399109844.jpg
#  17015653050042840439691206155947.jpg
# '24.11.6095, muhammad rizquna ali akbat.pdf'
#  bitcoin_stock_data.csv
#  bukti.jpg
# 'Colab Notebooks'
# 'Diberikan snapshot sistem berikut:'$'\n''Hitung isi mat... (1).gsheet'
# 'Diberikan snapshot sistem berikut:'$'\n''Hitung isi mat... (2).gsheet'
# 'Diberikan snapshot sistem berikut:'$'\n''Hitung isi mat... (3).gsheet'
# 'Diberikan snapshot sistem berikut:'$'\n''Hitung isi mat... (4).gsheet'
# 'Diberikan snapshot sistem berikut:'$'\n''Hitung isi mat... (5).gsheet'
# 'Diberikan snapshot sistem berikut:'$'\n''Hitung isi mat....gsheet'
# 'dokumen '
# 'Dokumen dari logika if03.pdf'
#  fg
# 'FORMULIR PEMBERKASAN_INDO.docx'
# 'FORMULIR PEMBERKASAN.pdf'
# 'ijazah lokal Darunnajah. pdf.pdf'
# 'ijazah negri. pdf.pdf'
#  IMG_20240815_180956.jpg
#  IMG_20260215_231758.jpg
#  IMG_20260215_231822.jpg
#  IMG_20260215_233305.jpg
#  IMG_20260215_233502.jpg
# 'KK MAULANA.pdf'
# ...

# %%
# Membaca dataset langsung dari Google Drive Anda
path_drive = "/content/drive/MyDrive/fg/bitcoin_stock_data.csv"

df_lokal = pd.read_csv(path_drive)
df_lokal.head(10)
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2014-09-17  465.864014  468.174011  452.421997  457.334015  457.334015
# 1  2014-09-18  456.859985  456.859985  413.104004  424.440002  424.440002
# 2  2014-09-19  424.102997  427.834991  384.532013  394.795990  394.795990
# 3  2014-09-20  394.673004  423.295990  389.882996  408.903992  408.903992
# 4  2014-09-21  408.084991  412.425995  393.181000  398.821014  398.821014
# 5  2014-09-22  399.100006  406.915985  397.130005  402.152008  402.152008
# 6  2014-09-23  402.091003  441.557007  396.196014  435.790985  435.790985
# 7  2014-09-24  435.897003  436.174011  419.204010  424.393005  424.393005
# 8  2014-09-25  424.017014  425.001007  400.802002  404.424988  404.424988
# 9  2014-09-26  403.946014  408.324005  395.546997  399.518005  399.518005
#
#      Volume
# 0  21056800
# 1  34483200
# 2  37919700
# 3  36863600
# 4  26580100
# 5  24127600
# 6  40739600
# 7  26268600
# 8  27491400
# 9  22882400

# %% [markdown]
# # 3.Dari API Kaggle

# %%
# Install dependencies
# !pip install kagglehub[pandas-datasets]

import kagglehub
from kagglehub import KaggleDatasetAdapter

# ✓ Urutan benar: adapter → handle → path
df_kaggle = kagglehub.load_dataset(
    KaggleDatasetAdapter.PANDAS,       # ← adapter
    "meetnagadia/bitcoin-stock-data-sept-17-2014-august-24-2021", # ← handle
    "BTC-USD.csv"                    # ← nama file dalam dataset
)

print("First 5 records:", df_kaggle.head())
# Out:
# ...
# /tmp/ipykernel_3193/306126403.py:8: DeprecationWarning: Use dataset_load() instead of load_dataset(). load_dataset() will be removed in a future version.
#   df_kaggle = kagglehub.load_dataset(
# Using Colab cache for faster access to the 'bitcoin-stock-data-sept-17-2014-august-24-2021' dataset.
# First 5 records:          Date        Open        High         Low       Close   Adj Close  \
# 0  2014-09-17  465.864014  468.174011  452.421997  457.334015  457.334015
# 1  2014-09-18  456.859985  456.859985  413.104004  424.440002  424.440002
# 2  2014-09-19  424.102997  427.834991  384.532013  394.795990  394.795990
# 3  2014-09-20  394.673004  423.295990  389.882996  408.903992  408.903992
# 4  2014-09-21  408.084991  412.425995  393.181000  398.821014  398.821014
#
#      Volume
# 0  21056800
# 1  34483200
# 2  37919700
# 3  36863600
# 4  26580100

# %%
# Membaca dataset yang diunggah dari lokal
df_lokal = pd.read_csv("bitcoin_stock_data.csv") # Sesuaikan nama file jika berbeda
df_lokal.head(10)
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2014-09-17  465.864014  468.174011  452.421997  457.334015  457.334015
# 1  2014-09-18  456.859985  456.859985  413.104004  424.440002  424.440002
# 2  2014-09-19  424.102997  427.834991  384.532013  394.795990  394.795990
# 3  2014-09-20  394.673004  423.295990  389.882996  408.903992  408.903992
# 4  2014-09-21  408.084991  412.425995  393.181000  398.821014  398.821014
# 5  2014-09-22  399.100006  406.915985  397.130005  402.152008  402.152008
# 6  2014-09-23  402.091003  441.557007  396.196014  435.790985  435.790985
# 7  2014-09-24  435.897003  436.174011  419.204010  424.393005  424.393005
# 8  2014-09-25  424.017014  425.001007  400.802002  404.424988  404.424988
# 9  2014-09-26  403.946014  408.324005  395.546997  399.518005  399.518005
#
#      Volume
# 0  21056800
# 1  34483200
# 2  37919700
# 3  36863600
# 4  26580100
# 5  24127600
# 6  40739600
# 7  26268600
# 8  27491400
# 9  22882400

# %% [markdown]
# # 4. Dari Tautan GitHub / Situs Web

# %%
# 4. Upload dataset Bitcoin dari link GITHUB/web
# Ganti URL di bawah ini dengan tautan RAW dari file CSV di GitHub Anda
url_github = "https://raw.githubusercontent.com/username_anda/nama_repo/main/BTC-Hourly.csv"

df_web = pd.read_csv(url_github)
df_web.head(10)
